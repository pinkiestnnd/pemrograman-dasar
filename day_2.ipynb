# %% [markdown]
# <a href="https://colab.research.google.com/github/pinkiestnnd/pemrograman-dasar/blob/main/day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numfloor = "1"
x = "1"
x = "2"
x = "10"
x = "nanad"
b = 1.23
c = True
d = False

#cara satu persatu
print(type(x))
print(type(b))
print(type(c))
print(type(d))

#cara gabung/otomatis
print (type(b)), type(c), type(d)

#list
#print
mahasiswa = ["Bambang", 1234, 165.7, False]

print(mahasiswa)
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
