# %% [markdown]
# <a href="https://colab.research.google.com/github/pinkiestnnd/pemrograman-dasar/blob/main/praktikum2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1

tegangan = 10
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan, arus, jenis_sel)
# Out:
# 10 6 Monocrystalline

# %%
# Jawaban Latihan 2

tegangan = 70
arus = 2.3
seri = False
label = "Trafo Distribusi"
impedansi = complex(5, 2)

print(type(tegangan))
print(type(arus))
print(type(seri))
print(type(label))
print(type(impedansi))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'complex'>

# %%
# Jawaban Latihan 3

nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(type(nama_unit))
print(type(jumlah_panel))
print(type(tegangan_keluaran))
print(type(sedang_beroperasi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Jawaban Latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

#cetak pembacaan pertama dan terakhir memakai indeks
print(tegangan_harian[0], tegangan_harian[5])

#tambahkan satu pembacaan baru 222.0 dengan append()
tegangan_harian.append(222.0)
print(tegangan_harian)

#cetak jumlah total data dengan len()
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
print(len(tegangan_harian))
# Out:
# 217.5 216.9
# [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# 7

# %%
# Jawaban Latihan 5

motor_listrik = {
    "nama": "Yadea E8S Pro",
    "kapasitas_MW": 200,
    "tegangan_kV": 15,
    "rpm" : 5000
}
print("nama:", motor_listrik["nama"])
print("kapasitas:", motor_listrik["kapasitas_MW"], "MW")
print("tegangan:", motor_listrik["tegangan_kV"], "kV")
print("rpm:", motor_listrik["rpm"])
# Out:
# nama: Yadea E8S Pro
# kapasitas: 200 MW
# tegangan: 15 kV
# rpm: 5000

# %%
# Jawaban Latihan 6

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]
print(pembangkit[2])

#ubah status salah satu unit
pembangkit[1]["status"] = "pemeliharaan"
print(pembangkit[1])

#tambahkan 1 unit baru dengan append()
pembangkit.append({"nama": "unit-4", "kapasitas_MW" : 120, "status": "operasi"})
print(pembangkit)
# Out:
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'pemeliharaan'}
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'pemeliharaan'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
